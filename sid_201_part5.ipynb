# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('whitegrid')

# %% [markdown]
# ---
# # sid_201 part 3
# ---

# %%
# read intervention data
intv_df = pd.read_csv('/sfxhome/gkang/tlc_data/intv_201.csv')
infection_trace_df = pd.read_csv('/sfxhome/gkang/tlc_data/infection_trace_201.csv')

# %%
# read chicago population data
household_df = pd.read_csv('/sfxhome/gkang/tlc_data/chicago_household.csv')
person_df = pd.read_csv('/sfxhome/gkang/tlc_data/chicago_person_info.csv')

# %% [markdown]
# ---
# ### merge with person and household tables
# ---

# %%
# join person data with intv data
person_intv_df = pd.merge(intv_df, person_df, left_on = 'pid', right_on = 'PID')
person_intv_df

# %%
# join all tables: person, household, intv
all_intv_df = pd.merge(person_intv, household_df, on = 'HID', how = 'inner')
all_intv_df

# %% [markdown]
# ---
# ### calculate incidence
# ---

# %%
intv_df
# Out:
#          ig_type  intervened        pid  rep  sid        tr
# 0              3          40  294524448    1  201  0.000135
# 1              3          40  294571037    1  201  0.000135
# 2              3          40  290699504    1  201  0.000135
# 3              3          40  288354895    1  201  0.000135
# 4              3          40  292271290    1  201  0.000135
# 5              3          40  294301186    1  201  0.000135
# 6              3          40  301957749    1  201  0.000135
# 7              3          40  290904046    1  201  0.000135
# 8              3          40  288207887    1  201  0.000135
# 9              3          40  294563871    1  201  0.000135
# 10             3          40  288990197    1  201  0.000135
# 11             2          34  294487786    1  201  0.000135
# 12             3          44  295386805    1  201  0.000135
# 13             2          22  288433388    1  201  0.000135
# 14             3          40  290872138    1  201  0.000135
# 15             3          40  302056503    1  201  0.000135
# 16             3          40  291097869    1  201  0.000135
# 17             3          40  289273663    1  201  0.000135
# 18             3          40  294446028    1  201  0.000135
# 19             3          40  291513010    1  201  0.000135
# 20             3          40  295083373    1  201  0.000135
# 21             3          40  294531212    1  201  0.000135
# 22             3          40  290276538    1  201  0.000135
# 23             3          40  291514098    1  201  0.000135
# 24             3          40  292956391    1  201  0.000135
# 25             3          40  291006005    1  201  0.000135
# 26             3          40  292091493    1  201  0.000135
# 27             3          40  291527192    1  201  0.000135
# 28             3          40  293703629    1  201  0.000135
# 29             3          40  294169315    1  201  0.000135
# ...          ...         ...        ...  ...  ...       ...
# 9434623        3          83  288118678    2  201  0.000166
# 9434624        3          83  292741670    2  201  0.000166
# 9434625        3          83  293156495    2  201  0.000166
# 9434626        3          83  287502619    2  201  0.000166
# 9434627        3          83  346055000    2  201  0.000166
# 9434628        3          83  295274091    2  201  0.000166
# 9434629        3          83  290215592    2  201  0.000166
# 9434630        3          83  288214226    2  201  0.000166
# 9434631        2          84  294238234    2  201  0.000166
# 9434632        2          84  294443125    2  201  0.000166
# 9434633        2          84  294674025    2  201  0.000166
# 9434634        2          84  302012802    2  201  0.000166
# 9434635        3          84  345629096    2  201  0.000166
# 9434636        3          84  287573569    2  201  0.000166
# 9434637        3          84  289389807    2  201  0.000166
# 9434638        3          84  347300479    2  201  0.000166
# 9434639        3          85  290440541    2  201  0.000166
# 9434640        3          85  292618275    2  201  0.000166
# 9434641        3          85  293288862    2  201  0.000166
# 9434642        3          85  345505224    2  201  0.000166
# 9434643        2          86  290752074    2  201  0.000166
# 9434644        3          86  292119622    2  201  0.000166
# 9434645        3          86  291572990    2  201  0.000166
# 9434646        3          86  294990127    2  201  0.000166
# 9434647        2          87  288013999    2  201  0.000166
# 9434648        2          87  345636694    2  201  0.000166
# 9434649        3          87  295125214    2  201  0.000166
# 9434650        2          89  292571119    2  201  0.000166
# 9434651        3          89  292528142    2  201  0.000166
# 9434652        2          95  291956763    2  201  0.000166
#
# [9434653 rows x 6 columns]

# %%
# daily incidence
daily_count = intv_df.groupby(['rep','intervened'])['ig_type'].count().reset_index()
daily_count
# Out:
#      rep  intervened  ig_type
# 0      0           8        1
# 1      0           9        4
# 2      0          10        2
# 3      0          12        8
# 4      0          13        4
# 5      0          14        9
# 6      0          15       11
# 7      0          16       19
# 8      0          17       16
# 9      0          18       32
# 10     0          19       23
# 11     0          20       38
# 12     0          21       34
# 13     0          22       55
# 14     0          23       54
# 15     0          24       83
# 16     0          25      103
# 17     0          26      129
# 18     0          27      153
# 19     0          28      179
# 20     0          29      201
# 21     0          30      269
# 22     0          31      332
# 23     0          32      445
# 24     0          33      496
# 25     0          34      600
# 26     0          35      803
# 27     0          36      956
# 28     0          37     1096
# 29     0          38     1405
# ..   ...         ...      ...
# 482    2         159        1
# 483    2         160        2
# 484    2         161        5
# 485    2         162        4
# 486    2         163        3
# 487    2         164        2
# 488    2         166        2
# 489    2         167        2
# 490    2         170        2
# 491    2         171        2
# 492    2         172        1
# 493    2         173        3
# 494    2         174        3
# 495    2         175        2
# 496    2         177        1
# 497    2         178        3
# 498    2         179        2
# 499    2         180        1
# 500    2         181        1
# 501    2         183        2
# 502    2         184        2
# 503    2         185        1
# 504    2         186        1
# 505    2         187        2
# 506    2         189        2
# 507    2         190        1
# 508    2         193        2
# 509    2         195        1
# 510    2         198        1
# 511    2         199        1
#
# [512 rows x 3 columns]

# %%
# cumulative incidence
cumulative_count = intv_df.groupby(['rep','intervened'])['ig_type'].count().cumsum().reset_index()
cumulative_count
# Out:
#      rep  intervened  ig_type
# 0      0           8        1
# 1      0           9        5
# 2      0          10        7
# 3      0          12       15
# 4      0          13       19
# 5      0          14       28
# 6      0          15       39
# 7      0          16       58
# 8      0          17       74
# 9      0          18      106
# 10     0          19      129
# 11     0          20      167
# 12     0          21      201
# 13     0          22      256
# 14     0          23      310
# 15     0          24      393
# 16     0          25      496
# 17     0          26      625
# 18     0          27      778
# 19     0          28      957
# 20     0          29     1158
# 21     0          30     1427
# 22     0          31     1759
# 23     0          32     2204
# 24     0          33     2700
# 25     0          34     3300
# 26     0          35     4103
# 27     0          36     5059
# 28     0          37     6155
# 29     0          38     7560
# ..   ...         ...      ...
# 482    2         159  9434596
# 483    2         160  9434598
# 484    2         161  9434603
# 485    2         162  9434607
# 486    2         163  9434610
# 487    2         164  9434612
# 488    2         166  9434614
# 489    2         167  9434616
# 490    2         170  9434618
# 491    2         171  9434620
# 492    2         172  9434621
# 493    2         173  9434624
# 494    2         174  9434627
# 495    2         175  9434629
# 496    2         177  9434630
# 497    2         178  9434633
# 498    2         179  9434635
# 499    2         180  9434636
# 500    2         181  9434637
# 501    2         183  9434639
# 502    2         184  9434641
# 503    2         185  9434642
# 504    2         186  9434643
# 505    2         187  9434645
# 506    2         189  9434647
# 507    2         190  9434648
# 508    2         193  9434650
# 509    2         195  9434651
# 510    2         198  9434652
# 511    2         199  9434653
#
# [512 rows x 3 columns]

# %% [markdown]
# ---
# ### Plot
# ---

# %%
df = intv_df.groupby(['rep','intervened'])['ig_type'].count().cumsum().reset_index()
df
# Out:
#      rep  intervened  ig_type
# 0      0           8        1
# 1      0           9        5
# 2      0          10        7
# 3      0          12       15
# 4      0          13       19
# 5      0          14       28
# 6      0          15       39
# 7      0          16       58
# 8      0          17       74
# 9      0          18      106
# 10     0          19      129
# 11     0          20      167
# 12     0          21      201
# 13     0          22      256
# 14     0          23      310
# 15     0          24      393
# 16     0          25      496
# 17     0          26      625
# 18     0          27      778
# 19     0          28      957
# 20     0          29     1158
# 21     0          30     1427
# 22     0          31     1759
# 23     0          32     2204
# 24     0          33     2700
# 25     0          34     3300
# 26     0          35     4103
# 27     0          36     5059
# 28     0          37     6155
# 29     0          38     7560
# ..   ...         ...      ...
# 482    2         159  9434596
# 483    2         160  9434598
# 484    2         161  9434603
# 485    2         162  9434607
# 486    2         163  9434610
# 487    2         164  9434612
# 488    2         166  9434614
# 489    2         167  9434616
# 490    2         170  9434618
# 491    2         171  9434620
# 492    2         172  9434621
# 493    2         173  9434624
# 494    2         174  9434627
# 495    2         175  9434629
# 496    2         177  9434630
# 497    2         178  9434633
# 498    2         179  9434635
# 499    2         180  9434636
# 500    2         181  9434637
# 501    2         183  9434639
# 502    2         184  9434641
# 503    2         185  9434642
# 504    2         186  9434643
# 505    2         187  9434645
# 506    2         189  9434647
# 507    2         190  9434648
# 508    2         193  9434650
# 509    2         195  9434651
# 510    2         198  9434652
# 511    2         199  9434653
#
# [512 rows x 3 columns]

# %%
df = intv_df.sample(500000)
sns.lmplot(x='intervened', y='ig_type', hue='rep', fit_reg=False, data=df)

# %%
cumulative_count = intv_df.\
    groupby(['rep','intervened'])['ig_type'].\
    count().\
    groupby(level=[0]).cumsum()

# %%
# plotting

#intv_df.groupby(['rep','intervened'])['ig_type'].count().cumsum().reset_index()
#sns.pointplot(x='intervened', y='ig_type', hue='rep', data=intv_df)
#sns.lmplot(x='intervened', y='ig_type', hue='rep', fit_reg=False, data=df)

# %% [markdown]
# ### Plot cumulative incidence

# %%
cumulative_count = intv_df.\
    groupby(['rep','intervened', 'tr'])['ig_type'].\
    count().\
    groupby(level=[0]).\
    cumsum().\
    reset_index()

# %%
sns.lmplot(x='intervened', y='ig_type', hue='rep', col='tr', fit_reg=False, data=cumulative_count.reset_index())

# %% [markdown]
# ### Plot daily infection??

# %%
blah = intv_df.\
    groupby(['rep','intervened', 'tr'])['ig_type'].\
    count().\
    groupby(level=[0]).mean()

# %%
blah
# Out:
# rep
# 0    8563.024823
# 1    7715.925275
# 2    7645.172113
# Name: ig_type, dtype: float64

# %%
blah = intv_df.\
    groupby(['rep','intervened', 'tr'])['ig_type'].\
    count().\
    groupby(level=[0, 1, 2]).\
    mean()

sns.lmplot(x='intervened', y='ig_type', hue='rep', col='tr',
           fit_reg=False, data=blah.reset_index())

# %% [markdown]
# # we plot stuff

# %%
df_rit = intv_df.\
    groupby(['rep', 'intervened', 'tr'])['ig_type'].\
    count().\
    reset_index()

sns.lmplot(x='intervened', y='ig_type',
           col='rep', row='tr',
           fit_reg=False, data=df_rit)

# %%
df = intv_df.\
    groupby(['rep', 'intervened', 'tr'])['ig_type'].\
    count().\
    groupby(level=['tr', 'intervened']).mean().reset_index()

# %%
sns.lmplot(x='intervened', y='ig_type', hue='tr',
           fit_reg=False, data=df)

# %% [markdown]
# # cumulative count

# %%
d = intv_df.\
    groupby(['rep', 'intervened', 'tr'])['ig_type'].\
    count().\
    reset_index()

# %%
d['cum_sum'] = d.groupby(['rep', 'tr'])['ig_type'].cumsum()

# %%
sns.lmplot(x='intervened', y='cum_sum',
           col='rep', row='tr',
           fit_reg=False, data=d)

# %%
g = sns.FacetGrid(d, row='tr', col='rep')
g.map_dataframe(sns.tsplot, time='intervened', value='cum_sum', condition='tr', unit = 'tr', data= d)

# %%
df = d.groupby(['tr', 'intervened'])['cum_sum'].mean().reset_index()
sns.lmplot(x='intervened', y='cum_sum', hue='tr',
           fit_reg=False, data=df)

# %%
sns.tsplot(time='intervened', value='cum_sum', condition='tr', unit = 'tr', data=df)

# %%
c = sns.plotting_context('notebook', font_scale=1)
with c:
    sns.tsplot(time='intervened', value='cum_sum', condition='tr', unit = 'tr', data=df)
